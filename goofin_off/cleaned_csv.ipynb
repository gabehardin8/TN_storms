# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlalchemy as sql
import seaborn as sns
import os

# %%
tn_details_decade = pd.read_csv('tn_details_decade.csv')
tn_details_decade.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           201607          8        1755         201607        8      1755
# 1           201607          8        1810         201607        8      1810
# 2           201607          8        1910         201607        8      1910
# 3           201607          8        1840         201607        8      1840
# 4           201607         14        1540         201607       14      1540
#
#    EPISODE_ID  EVENT_ID      STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0      105872    635287  TENNESSEE          47  ...       0.56           W
# 1      105872    635296  TENNESSEE          47  ...       1.32         WSW
# 2      105872    635301  TENNESSEE          47  ...       1.38           S
# 3      105872    635299  TENNESSEE          47  ...       0.69           N
# 4      105948    635802  TENNESSEE          47  ...       1.32         ENE
#
#      END_LOCATION BEGIN_LAT  BEGIN_LON END_LAT END_LON  \
# ...

# %%
tn_fatalities_decade = pd.read_csv('tn_fatalities_decade.csv')
tn_fatalities_decade.head()
# Out:
#    FAT_YEARMONTH  FAT_DAY  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0         201607        8        30294    635269             D
# 1         201607        8        30292    635264             D
# 2         201607        8        30293    635264             D
# 3         201605        4        30198    627799             D
# 4         201607       14        31229    638992             D
#
#          FATALITY_DATE  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION
# 0  07/08/2016 00:00:00          66.0            F     Outside/Open Areas
# 1  07/08/2016 00:00:00          60.0            M                Camping
# 2  07/08/2016 00:00:00          47.0            F                Camping
# 3  05/04/2016 00:00:00          64.0            M  Vehicle/Towed Trailer
# 4  07/14/2016 00:00:00          65.0            F             Under Tree

# %%
tn_fatalities_decade
# Out:
#      FAT_YEARMONTH  FAT_DAY  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0           201607        8        30294    635269             D
# 1           201607        8        30292    635264             D
# 2           201607        8        30293    635264             D
# 3           201605        4        30198    627799             D
# 4           201607       14        31229    638992             D
# ..             ...      ...          ...       ...           ...
# 200         202507       21        59550   1283432             D
# 201         202508       12        59517   1283123             D
# 202         202508       12        59518   1283123             D
# 203         202508       12        59519   1283123             D
# 204         202508       12        59815   1287783             D
#
#            FATALITY_DATE  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION
# 0    07/08/2016 00:00:00          66.0            F     Outside/Open Areas
# ...

# %%
tn_fatalities_decade.columns
# Out:
# Index(['FAT_YEARMONTH', 'FAT_DAY', 'FATALITY_ID', 'EVENT_ID', 'FATALITY_TYPE',
#        'FATALITY_DATE', 'FATALITY_AGE', 'FATALITY_SEX', 'FATALITY_LOCATION'],
#       dtype='object')

# %%
fatalities_cleaned = tn_fatalities_decade[[
    'FATALITY_DATE','FATALITY_ID', 'EVENT_ID', 'FATALITY_TYPE', 'FATALITY_AGE', 'FATALITY_SEX', 'FATALITY_LOCATION'
]]
fatalities_cleaned.head()
# Out:
#          FATALITY_DATE  FATALITY_ID  EVENT_ID FATALITY_TYPE  FATALITY_AGE  \
# 0  07/08/2016 00:00:00        30294    635269             D          66.0
# 1  07/08/2016 00:00:00        30292    635264             D          60.0
# 2  07/08/2016 00:00:00        30293    635264             D          47.0
# 3  05/04/2016 00:00:00        30198    627799             D          64.0
# 4  07/14/2016 00:00:00        31229    638992             D          65.0
#
#   FATALITY_SEX      FATALITY_LOCATION
# 0            F     Outside/Open Areas
# 1            M                Camping
# 2            F                Camping
# 3            M  Vehicle/Towed Trailer
# 4            F             Under Tree

# %%
fatalities_cleaned['FATALITY_DATE'] = fatalities_cleaned['FATALITY_DATE'].str[:-5]
fatalities_cleaned.head()
# Out:
# C:\Users\plann\AppData\Local\Temp\ipykernel_29612\3970764057.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fatalities_cleaned['FATALITY_DATE'] = fatalities_cleaned['FATALITY_DATE'].str[:-5]
#     FATALITY_DATE  FATALITY_ID  EVENT_ID FATALITY_TYPE  FATALITY_AGE  \
# 0  07/08/2016 00:        30294    635269             D          66.0
# 1  07/08/2016 00:        30292    635264             D          60.0
# 2  07/08/2016 00:        30293    635264             D          47.0
# 3  05/04/2016 00:        30198    627799             D          64.0
# 4  07/14/2016 00:        31229    638992             D          65.0
#
#   FATALITY_SEX      FATALITY_LOCATION
# 0            F     Outside/Open Areas
# ...

# %%
fatalities_cleaned.dtypes
# Out:
# FATALITY_DATE         object
# FATALITY_ID            int64
# EVENT_ID               int64
# FATALITY_TYPE         object
# FATALITY_AGE         float64
# FATALITY_SEX          object
# FATALITY_LOCATION     object
# dtype: object

# %%
fatalities_cleaned.to_csv(r'C:\Users\plann\Documents\Nashville Software School\Python\Capstone\fatalities_cleaned.csv',index = False)

# %%
tn_locations_decade = pd.read_csv('tn_locations_decade.csv')
tn_locations_decade.head()
# Out:
#    YEARMONTH  EPISODE_ID  EVENT_ID  LOCATION_INDEX  RANGE AZIMUTH  \
# 0     201607      105872    635287               1   0.56       W
# 1     201607      105872    635296               1   1.32     WSW
# 2     201607      105872    635301               1   1.38       S
# 3     201607      105872    635299               1   0.69       N
# 4     201607      105948    635802               1   1.32     ENE
#
#          LOCATION  LATITUDE  LONGITUDE     LAT2     LON2
# 0            JENA     35.65     -84.18  3539000  8410800
# 1          PITNER     35.87     -83.77  3552200  8346200
# 2            DILL     35.56     -85.20  3533600  8512000
# 3  TELLICO PLAINS     35.38     -84.30  3522800  8418000
# 4          LOVELL     35.91     -84.13  3554600   847800

# %%
tn_details_decade.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           201607          8        1755         201607        8      1755
# 1           201607          8        1810         201607        8      1810
# 2           201607          8        1910         201607        8      1910
# 3           201607          8        1840         201607        8      1840
# 4           201607         14        1540         201607       14      1540
#
#    EPISODE_ID  EVENT_ID      STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0      105872    635287  TENNESSEE          47  ...       0.56           W
# 1      105872    635296  TENNESSEE          47  ...       1.32         WSW
# 2      105872    635301  TENNESSEE          47  ...       1.38           S
# 3      105872    635299  TENNESSEE          47  ...       0.69           N
# 4      105948    635802  TENNESSEE          47  ...       1.32         ENE
#
#      END_LOCATION BEGIN_LAT  BEGIN_LON END_LAT END_LON  \
# ...

# %%
tn_details_decade.columns
# Out:
# Index(['BEGIN_YEARMONTH', 'BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',
#        'END_DAY', 'END_TIME', 'EPISODE_ID', 'EVENT_ID', 'STATE', 'STATE_FIPS',
#        'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'CZ_TYPE', 'CZ_FIPS', 'CZ_NAME',
#        'WFO', 'BEGIN_DATE_TIME', 'CZ_TIMEZONE', 'END_DATE_TIME',
#        'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'CATEGORY', 'TOR_F_SCALE',
#        'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO', 'TOR_OTHER_CZ_STATE',
#        'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME', 'BEGIN_RANGE',
#        'BEGIN_AZIMUTH', 'BEGIN_LOCATION', 'END_RANGE', 'END_AZIMUTH',
#        'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
#        'EPISODE_NARRATIVE', 'EVENT_NARRATIVE', 'DATA_SOURCE'],
#       dtype='object')

# %%
details_cleaned = tn_details_decade[['BEGIN_DATE_TIME','END_DATE_TIME','EPISODE_ID', 'EVENT_ID',
       'EVENT_TYPE', 'CZ_TYPE', 'CZ_FIPS', 'CZ_NAME',
       'WFO', 'CZ_TIMEZONE', 
       'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
       'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
       'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'TOR_F_SCALE',
       'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO',
       'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME', 'BEGIN_RANGE',
       'BEGIN_AZIMUTH', 'BEGIN_LOCATION', 'END_RANGE', 'END_AZIMUTH',
       'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
       'EPISODE_NARRATIVE', 'EVENT_NARRATIVE']]
details_cleaned.head()
# Out:
#       BEGIN_DATE_TIME       END_DATE_TIME  EPISODE_ID  EVENT_ID  \
# 0  08-JUL-16 17:55:00  08-JUL-16 17:55:00      105872    635287
# 1  08-JUL-16 18:10:00  08-JUL-16 18:10:00      105872    635296
# 2  08-JUL-16 19:10:00  08-JUL-16 19:10:00      105872    635301
# 3  08-JUL-16 18:40:00  08-JUL-16 18:40:00      105872    635299
# 4  14-JUL-16 15:40:00  14-JUL-16 15:40:00      105948    635802
#
#           EVENT_TYPE CZ_TYPE  CZ_FIPS  CZ_NAME  WFO CZ_TIMEZONE  ...  \
# 0  Thunderstorm Wind       C      105   LOUDON  MRX       EST-5  ...
# 1  Thunderstorm Wind       C      155   SEVIER  MRX       EST-5  ...
# 2  Thunderstorm Wind       C        7  BLEDSOE  MRX       CST-6  ...
# 3  Thunderstorm Wind       C      123   MONROE  MRX       EST-5  ...
# 4               Hail       C       93     KNOX  MRX       EST-5  ...
#
#    BEGIN_LOCATION  END_RANGE  END_AZIMUTH    END_LOCATION BEGIN_LAT BEGIN_LON  \
# 0            JENA       0.56            W            JENA     35.65    -84.18
# ...

# %%
details_cleaned.dtypes
# Out:
# BEGIN_DATE_TIME       object
# END_DATE_TIME         object
# EPISODE_ID             int64
# EVENT_ID               int64
# EVENT_TYPE            object
# CZ_TYPE               object
# CZ_FIPS                int64
# CZ_NAME               object
# WFO                   object
# CZ_TIMEZONE           object
# INJURIES_DIRECT        int64
# INJURIES_INDIRECT      int64
# DEATHS_DIRECT          int64
# DEATHS_INDIRECT        int64
# DAMAGE_PROPERTY       object
# DAMAGE_CROPS          object
# SOURCE                object
# MAGNITUDE            float64
# MAGNITUDE_TYPE        object
# FLOOD_CAUSE           object
# TOR_F_SCALE           object
# TOR_LENGTH           float64
# TOR_WIDTH            float64
# TOR_OTHER_WFO         object
# TOR_OTHER_CZ_FIPS    float64
# TOR_OTHER_CZ_NAME     object
# BEGIN_RANGE          float64
# BEGIN_AZIMUTH         object
# BEGIN_LOCATION        object
# END_RANGE            float64
# END_AZIMUTH           object
# END_LOCATION          object
# ...

# %%
details_cleaned['DAMAGE_PROPERTY'] = details_cleaned['DAMAGE_PROPERTY'].astype(str).str.replace('0.00K','0').str.replace('.','').str.replace('K','0').str.replace('M','0000').str.replace('B','0000000').str.replace('nan','0').astype(int)
details_cleaned['DAMAGE_PROPERTY'][10:20]
# Out:
# C:\Users\plann\AppData\Local\Temp\ipykernel_29612\380653213.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details_cleaned['DAMAGE_PROPERTY'] = details_cleaned['DAMAGE_PROPERTY'].astype(str).str.replace('0.00K','0').str.replace('.','').str.replace('K','0').str.replace('M','0000').str.replace('B','0000000').str.replace('nan','0').astype(int)
# 10    3000
# 11    3000
# 12    5000
# 13    1000
# 14       0
# 15       0
# 16       0
# 17       0
# 18       0
# 19       0
# Name: DAMAGE_PROPERTY, dtype: int64

# %%
details_cleaned['DAMAGE_CROPS'] = details_cleaned['DAMAGE_CROPS'].astype(str).str.replace('0.00K','0').str.replace('.','').str.replace('K','0').str.replace('M','0000').str.replace('B','0000000').str.replace('nan','0').astype(int)
details_cleaned['DAMAGE_CROPS'][25:50]
# Out:
# C:\Users\plann\AppData\Local\Temp\ipykernel_29612\1443061333.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   details_cleaned['DAMAGE_CROPS'] = details_cleaned['DAMAGE_CROPS'].astype(str).str.replace('0.00K','0').str.replace('.','').str.replace('K','0').str.replace('M','0000').str.replace('B','0000000').str.replace('nan','0').astype(int)
# 25    0
# 26    0
# 27    0
# 28    0
# 29    0
# 30    0
# 31    0
# 32    0
# 33    0
# 34    0
# 35    0
# 36    0
# 37    0
# 38    0
# 39    0
# 40    0
# 41    0
# 42    0
# 43    0
# 44    0
# 45    0
# 46    0
# 47    0
# 48    0
# 49    0
# Name: DAMAGE_CROPS, dtype: int64

# %%
details_cleaned['SOURCE']
# Out:
# 0                   Public
# 1           State Official
# 2           State Official
# 3           State Official
# 4          Trained Spotter
#                ...
# 15459         Social Media
# 15460                 AWSS
# 15461      Trained Spotter
# 15462    Emergency Manager
# 15463               Public
# Name: SOURCE, Length: 15464, dtype: object

# %%
details_cleaned.to_csv(r'C:\Users\plann\Documents\Nashville Software School\Python\Capstone\details_cleaned.csv',index = False)

# %%
details_cleaned[['BEGIN_DATE_TIME', 'END_DATE_TIME',  'EPISODE_ID', 'EVENT_ID', 'FLOOD_CAUSE',	'CATEGORY', 'TOR_F_SCALE',	'TOR_LENGTH',	'TOR_WIDTH', 'TOR_OTHER_WFO',	'TOR_OTHER_CZ_FIPS',	'TOR_OTHER_CZ_NAME']].loc[details_cleaned['BEGIN_DATE_TIME']== '08-JUL-16 17:55:00']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 details_cleaned[['BEGIN_DATE_TIME', 'END_DATE_TIME',  'EPISODE_ID', 'EVENT_ID', 'FLOOD_CAUSE',	'CATEGORY', 'TOR_F_SCALE',	'TOR_LENGTH',	'TOR_WIDTH', 'TOR_OTHER_WFO',	'TOR_OTHER_CZ_FIPS',	'TOR_OTHER_CZ_NAME']].loc[details_cleaned['BEGIN_DATE_TIME']== '08-JUL-16 17:55:00']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
# ...

# %%
sci_desc = ['FLOOD_CAUSE','CATEGORY','TOR_F_SCALE','TOR_LENGTH','TOR_WIDTH', 'TOR_OTHER_WFO','TOR_OTHER_CZ_FIPS','TOR_OTHER_CZ_NAME']

for desc in sci_desc:
    print(details_cleaned[f'{desc}'].loc[details_cleaned[f'{desc}'] != 'NaN'])

# %%
details_cleaned.columns

# %%
details_columns = ['BEGIN_DATE_TIME', 'END_DATE_TIME', 'EPISODE_ID', 'EVENT_ID',
       'EVENT_TYPE', 'CZ_TYPE', 'CZ_FIPS', 'CZ_NAME', 'WFO', 'CZ_TIMEZONE',
       'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
       'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
       'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'CATEGORY', 'TOR_F_SCALE',
       'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO', 'TOR_OTHER_CZ_FIPS',
       'TOR_OTHER_CZ_NAME', 'BEGIN_RANGE', 'BEGIN_AZIMUTH', 'BEGIN_LOCATION',
       'END_RANGE', 'END_AZIMUTH', 'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON',
       'END_LAT', 'END_LON', 'EPISODE_NARRATIVE', 'EVENT_NARRATIVE']

# %%
columns_df = pd.DataFrame(details_columns, columns = ['list'])
columns_df

# %%
columns_df['list'].str.lower()

# %%
tn_locations_decade.columns

# %%
tn_locations_decade.dtypes

# %%
tn_locations_decade['LAT2'].describe()

# %%
locations_cleaned = tn_locations_decade[['YEARMONTH', 'EPISODE_ID', 'EVENT_ID', 'LOCATION_INDEX', 'RANGE',
       'AZIMUTH', 'LOCATION', 'LATITUDE', 'LONGITUDE']]

locations_cleaned = locations_cleaned.drop_duplicates()
locations_cleaned

# %%
locations_cleaned.to_csv(r'C:\Users\plann\Documents\Nashville Software School\Python\Capstone\locations_cleaned.csv',index = False)
