# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fatalities_2016 = pd.read_csv('StormEvents_fatalities-ftp_v1.0_d2016_c20260323.csv')
fatalities_2016.head()
# Out:
#    FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0         201601       24         0        29746    609334             I
# 1         201601       24         0        29747    609340             I
# 2         201601       24         0        29748    609340             I
# 3         201601       17         0        29701    609389             D
# 4         201601       17         0        29702    609389             D
#
#          FATALITY_DATE  FATALITY_AGE FATALITY_SEX    FATALITY_LOCATION
# 0  01/24/2016 00:00:00           NaN            M   Outside/Open Areas
# 1  01/24/2016 00:00:00          70.0            M       Permanent Home
# 2  01/24/2016 00:00:00          76.0            M       Permanent Home
# 3  01/17/2016 00:00:00          58.0            M  Mobile/Trailer Home
# 4  01/17/2016 00:00:00          51.0            F  Mobile/Trailer Home

# %%
fatalities_2016[300:305]
# Out:
#      FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 300         201610        9         0        31819    663564             D
# 301         201610        9         0        31736    663637             D
# 302         201610        8         0        31813    663955             D
# 303         201610        8         0        31814    663955             D
# 304         201610        9         0        31812    663986             I
#
#            FATALITY_DATE  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION
# 300  10/09/2016 00:00:00          70.0            M  Vehicle/Towed Trailer
# 301  10/09/2016 00:00:00           NaN            F  Vehicle/Towed Trailer
# 302  10/08/2016 00:00:00           NaN          NaN  Vehicle/Towed Trailer
# 303  10/08/2016 00:00:00           NaN          NaN  Vehicle/Towed Trailer
# 304  10/09/2016 00:00:00           NaN          NaN     Outside/Open Areas

# %%
fatalities_2016.tail()
# Out:
#      FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 665         201608       10         0        30420    642444             D
# 666         201608        7         0        30453    643385             I
# 667         201607       21         0        31235    653173             D
# 668         201607       22         0        31236    653174             D
# 669         201601        4         0        59501    599336             D
#
#            FATALITY_DATE  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION
# 665  08/10/2016 00:00:00          35.0            M               In Water
# 666  08/07/2016 00:00:00           NaN            M  Vehicle/Towed Trailer
# 667  07/21/2016 00:00:00          67.0            M               In Water
# 668  07/22/2016 00:00:00          71.0            M               In Water
# 669  01/04/2016 00:00:00          81.0            F                  Other

# %%
start = 0

for index, row in fatalities_2016.iterrows():
    df_len =  +1
print(df_len)
# Out:
# 1

# %%
def dot_com():
    return 100 + 100

# %%
dot_com()
# Out:
# 200

# %%
fatalities_2016.shape
# Out:
# (670, 10)

# %%
def crap():
    if fatalities_2016.shape != (670, 10):
        print('oops!')
    else: print('thank God')

# %%
crap()
# Out:
# thank God

# %%
fatalities_2016['FATALITY_DATE'] = pd.to_datetime(fatalities_2016['FATALITY_DATE'])

# %%
fatalities_2016
# Out:
#      FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0           201601       24         0        29746    609334             I
# 1           201601       24         0        29747    609340             I
# 2           201601       24         0        29748    609340             I
# 3           201601       17         0        29701    609389             D
# 4           201601       17         0        29702    609389             D
# ..             ...      ...       ...          ...       ...           ...
# 665         201608       10         0        30420    642444             D
# 666         201608        7         0        30453    643385             I
# 667         201607       21         0        31235    653173             D
# 668         201607       22         0        31236    653174             D
# 669         201601        4         0        59501    599336             D
#
#     FATALITY_DATE  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION
# ...

# %%
fatalities_2016['FATALITY_LOCATION'].unique()
# Out:
# array(['Outside/Open Areas', 'Permanent Home', 'Mobile/Trailer Home',
#        'Vehicle/Towed Trailer', 'In Water', 'Boating',
#        'Permanent Structure', 'Heavy Equipment/Construction',
#        'Under Tree', 'Unknown', 'Camping', 'Church', 'Other', 'Business'],
#       dtype=object)

# %%
fatalities_2016.loc[fatalities_2016['FATALITY_LOCATION']== 'Mobile/Trailer Home'].shape[0]
# Out:
# 19

# %%
def dot_loc(df, column):
    loc_return = print(f"{df}.loc[{df}['{column}'] == ]") #curly braces {} evaluate and expression and convert it to a string
    return loc_return

# %%
dot_loc('fatalities_2016','FATALITY_LOCATION')
# Out:
# fatalities_2016.loc[fatalities_2016['FATALITY_LOCATION'] == ]

# %%
fatalities_2016.loc[fatalities_2016['FATALITY_LOCATION'] == 'In Water']
# Out:
#      FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 12          201602       25         0        31536    614284             D
# 13          201607       16         0        31537    642919             I
# 14          201607       16         0        31538    642919             I
# 15          201606        2         0        31568    646454             D
# 18          201601       30         0        29782    611127             I
# ..             ...      ...       ...          ...       ...           ...
# 660         201603       30         0        30190    626163             D
# 663         201603       19         0        30192    626681             D
# 665         201608       10         0        30420    642444             D
# 667         201607       21         0        31235    653173             D
# 668         201607       22         0        31236    653174             D
#
#     FATALITY_DATE  FATALITY_AGE FATALITY_SEX FATALITY_LOCATION
# ...

# %%
len(fatalities_2016['EVENT_ID'].unique())
# Out:
# 448

# %%
len(fatalities_2016['FATALITY_ID'].unique())
# Out:
# 670

# %%
fatalities_2016['EVENT_ID'].unique()
# Out:
# array([609334, 609340, 609389, 610536, 610537, 610538, 610540, 614284,
#        642919, 646454, 646433, 611127, 611146, 611231, 611879, 611941,
#        612214, 613720, 613990, 614361, 614452, 614453, 614456, 614502,
#        625127, 646936, 647189, 646102, 648972, 649272, 650006, 653889,
#        654484, 654515, 654517, 662401, 663221, 665859, 654249, 657571,
#        657762, 661830, 662323, 678358, 618485, 619063, 622678, 622707,
#        624280, 624287, 626144, 626149, 626153, 626374, 630266, 630502,
#        631166, 632694, 611168, 611703, 612511, 613449, 613659, 614190,
#        614266, 614269, 614449, 615978, 615982, 616172, 616788, 618350,
#        618535, 657939, 619687, 658361, 658547, 622181, 622203, 622670,
#        623305, 623339, 649245, 641438, 635674, 653540, 643377, 643399,
#        658343, 669430, 614678, 615221, 615222, 615223, 615345, 615772,
#        616052, 616169, 616171, 616387, 616498, 616502, 616503, 616508,
# ...

# %%
fatalities_2016
# Out:
#      FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0           201601       24         0        29746    609334             I
# 1           201601       24         0        29747    609340             I
# 2           201601       24         0        29748    609340             I
# 3           201601       17         0        29701    609389             D
# 4           201601       17         0        29702    609389             D
# ..             ...      ...       ...          ...       ...           ...
# 665         201608       10         0        30420    642444             D
# 666         201608        7         0        30453    643385             I
# 667         201607       21         0        31235    653173             D
# 668         201607       22         0        31236    653174             D
# 669         201601        4         0        59501    599336             D
#
#     FATALITY_DATE  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION
# ...

# %%
user_input = input("say something: ")
# Out:
# say something:  i'm giving up on you

# %%
print('you entered :', user_input)
# Out:
# you entered : i'm giving up on you

# %%
death_charts = fatalities_2016.loc[(fatalities_2016['FAT_YEARMONTH']== 201601) & (fatalities_2016['FAT_DAY']== 24)]
death_charts
# Out:
#      FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0           201601       24         0        29746    609334             I
# 1           201601       24         0        29747    609340             I
# 2           201601       24         0        29748    609340             I
# 142         201601       24         0        30037    617356             I
# 144         201601       24         0        30038    617358             I
# 225         201601       24         0        30081    620870             I
# 232         201601       24         0        30105    621219             D
# 574         201601       24         0        29638    608730             D
# 575         201601       24         0        29639    608730             D
# 576         201601       24         0        29669    608906             D
# 579         201601       24         0        29749    609333             I
#
#     FATALITY_DATE  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION
# ...

# %%
for index, row in death_charts.iterrows():
    print('ha!')
# Out:
# ha!
# ha!
# ha!
# ha!
# ha!
# ha!
# ha!
# ha!
# ha!
# ha!
# ha!

# %%
gender_fatalities = fatalities_2016[['FATALITY_SEX','FATALITY_ID']]

# %%
gender_fatalities.dtypes
# Out:
# FATALITY_SEX    object
# FATALITY_ID      int64
# dtype: object

# %%
gender_fatalities['FATALITY_ID'] = gender_fatalities['FATALITY_ID'].astype(str)
gender_fatalities['FATALITY_SEX'] = gender_fatalities['FATALITY_SEX'].astype(str)
# Out:
# C:\Users\plann\AppData\Local\Temp\ipykernel_24500\123896705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gender_fatalities['FATALITY_ID'] = gender_fatalities['FATALITY_ID'].astype(str)
# C:\Users\plann\AppData\Local\Temp\ipykernel_24500\123896705.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gender_fatalities['FATALITY_SEX'] = gender_fatalities['FATALITY_SEX'].astype(str)

# %%
grouped_gf = gender_fatalities.groupby('FATALITY_SEX').count().reset_index()
grouped_gf
# Out:
#   FATALITY_SEX  FATALITY_ID
# 0            F          194
# 1            M          447
# 2          nan           29

# %%
plt.bar(data = grouped_gf, x = 'FATALITY_SEX', y= 'FATALITY_ID',width =4, height = 6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.bar(data = grouped_gf, x = 'FATALITY_SEX', y= 'FATALITY_ID',width =4, height = 6)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2990, in bar(x, height, width, bottom, align, data, **kwargs)
#    2979 @_copy_docstring_and_deprecators(Axes.bar)
#    2980 def bar(
#    2981     x: float | ArrayLike,
#    (...)   2988     **kwargs,
#    2989 ) -> BarContainer:
# -> 2990     return gca().bar(
#    2991         x,
#    2992         height,
#    2993         width=width,
#    2994         bottom=bottom,
#    2995         align=align,
#    2996         **({"data": data} if data is not None else {}),
#    2997         **kwargs,
#    2998     )
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:1553, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
# ...
