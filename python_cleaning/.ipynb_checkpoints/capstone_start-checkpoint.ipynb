# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlalchemy as sql
import seaborn as sns
import os

# %%
#saving csvs to variables

fatalities_2016 = pd.read_csv('../noaa_data/StormEvents_fatalities-ftp_v1.0_d2016_c20260323.csv')
fatalities_2017 = pd.read_csv('../noaa_data/StormEvents_fatalities-ftp_v1.0_d2017_c20260519.csv')
fatalities_2018 = pd.read_csv('../noaa_data/StormEvents_fatalities-ftp_v1.0_d2018_c20260323.csv')
fatalities_2019 = pd.read_csv('../noaa_data/StormEvents_fatalities-ftp_v1.0_d2019_c20260323.csv')
fatalities_2020 = pd.read_csv('../noaa_data/StormEvents_fatalities-ftp_v1.0_d2020_c20260323.csv')
fatalities_2021 = pd.read_csv('../noaa_data/StormEvents_fatalities-ftp_v1.0_d2021_c20260323.csv')
fatalities_2022 = pd.read_csv('../noaa_data/StormEvents_fatalities-ftp_v1.0_d2022_c20260625.csv')
fatalities_2023 = pd.read_csv('../noaa_data/StormEvents_fatalities-ftp_v1.0_d2023_c20260323.csv')
fatalities_2024 = pd.read_csv('../noaa_data/StormEvents_fatalities-ftp_v1.0_d2024_c20260421.csv')
fatalities_2025 = pd.read_csv('../noaa_data/StormEvents_fatalities-ftp_v1.0_d2025_c20260526.csv')

# %%
#combining separate csv records of storm fatalities

fatalities_decade = pd.concat(
    [fatalities_2016, fatalities_2017, fatalities_2018, fatalities_2019, fatalities_2020, fatalities_2021, fatalities_2022, fatalities_2023, fatalities_2024, fatalities_2025]
)

# %%
fatalities_decade
# Out:
#      FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0           201601       24         0        29746    609334             I
# 1           201601       24         0        29747    609340             I
# 2           201601       24         0        29748    609340             I
# 3           201601       17         0        29701    609389             D
# 4           201601       17         0        29702    609389             D
# ..             ...      ...       ...          ...       ...           ...
# 890         202503        1         0        58955   1247889             I
# 891         202503       16         0        58978   1248504             D
# 892         202503       16         0        58979   1248504             D
# 893         202503        8         0        58977   1243740             D
# 894         202502        7         0        58771   1239660             I
#
# ...

# %%
#ensuring there are no duplicate records the the combined dataframe
fatalities_decade.drop_duplicates().shape
# Out:
# (10146, 10)

# %%
fatalities_decade = fatalities_decade.reset_index(drop=True)
fatalities_decade.head()
# Out:
#    FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0         201601       24         0        29746    609334             I
# 1         201601       24         0        29747    609340             I
# 2         201601       24         0        29748    609340             I
# 3         201601       17         0        29701    609389             D
# 4         201601       17         0        29702    609389             D
#
#          FATALITY_DATE  FATALITY_AGE FATALITY_SEX    FATALITY_LOCATION
# 0  01/24/2016 00:00:00           NaN            M   Outside/Open Areas
# 1  01/24/2016 00:00:00          70.0            M       Permanent Home
# 2  01/24/2016 00:00:00          76.0            M       Permanent Home
# 3  01/17/2016 00:00:00          58.0            M  Mobile/Trailer Home
# 4  01/17/2016 00:00:00          51.0            F  Mobile/Trailer Home

# %%
#setting storm detail csvs to variables

details_2016 = pd.read_csv('../noaa_data/StormEvents_details-ftp_v1.0_d2016_c20260323.csv')
details_2017 = pd.read_csv('../noaa_data/StormEvents_details-ftp_v1.0_d2017_c20260519.csv')
details_2018 = pd.read_csv('../noaa_data/StormEvents_details-ftp_v1.0_d2018_c20260323.csv')
details_2019 = pd.read_csv('../noaa_data/StormEvents_details-ftp_v1.0_d2019_c20260323.csv')
details_2020 = pd.read_csv('../noaa_data/StormEvents_details-ftp_v1.0_d2020_c20260323.csv')
details_2021 = pd.read_csv('../noaa_data/StormEvents_details-ftp_v1.0_d2021_c20260323.csv')
details_2022 = pd.read_csv('../noaa_data/StormEvents_details-ftp_v1.0_d2022_c20260625.csv')
details_2023 = pd.read_csv('../noaa_data/StormEvents_details-ftp_v1.0_d2023_c20260323.csv')
details_2024 = pd.read_csv('../noaa_data/StormEvents_details-ftp_v1.0_d2024_c20260421.csv')
details_2025 = pd.read_csv('../noaa_data/StormEvents_details-ftp_v1.0_d2025_c20260526.csv')

# %%
#combining separate csv records of storm details

details_decade = pd.concat(
    [details_2016 ,details_2017 ,details_2018 ,details_2019 ,details_2020 ,details_2021 ,details_2022 ,details_2023 ,details_2024 ,details_2025]
)

# %%
details_decade
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 0               201606         22        2010         201606       22
# 1               201607         15        1715         201607       15
# 2               201607         15        1725         201607       15
# 3               201607         16        1246         201607       16
# 4               201607          8        1755         201607        8
# ...                ...        ...         ...            ...      ...
# 72355           202501         10         700         202501       10
# 72356           202501         21        1300         202501       21
# 72357           202501         21        1300         202501       21
# 72358           202501         21        1400         202501       21
# 72359           202501         21        1400         202501       21
#
#        END_TIME  EPISODE_ID  EVENT_ID           STATE  STATE_FIPS  ...  \
# ...

# %%
details_decade.drop_duplicates().shape
# Out:
# (653920, 51)

# %%
# filtering storm details to only include records from Tennessee

tn_details_decade = details_decade.loc[details_decade['STATE'] == 'TENNESSEE']

tn_details_decade.shape
# Out:
# (15464, 51)

# %%
tn_details_decade = tn_details_decade.reset_index(drop=True)
tn_details_decade
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 0               201607          8        1755         201607        8
# 1               201607          8        1810         201607        8
# 2               201607          8        1910         201607        8
# 3               201607          8        1840         201607        8
# 4               201607         14        1540         201607       14
# ...                ...        ...         ...            ...      ...
# 15459           202509         27        1200         202509       27
# 15460           202509         27        1035         202509       27
# 15461           202509         27        1053         202509       27
# 15462           202509         27        1145         202509       27
# 15463           202509          6         400         202509        6
#
#        END_TIME  EPISODE_ID  EVENT_ID      STATE  STATE_FIPS  ...  END_RANGE  \
# ...

# %%
# inner joining fatality records with storm details to filter only fatalities that occurred in TN

tn_fatalities_decade = pd.merge(tn_details_decade, fatalities_decade, how = 'inner', on = 'EVENT_ID')
tn_fatalities_decade.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           201607          8        1728         201607        8      1728
# 1           201607          8        1726         201607        8      1726
# 2           201607          8        1726         201607        8      1726
# 3           201605          4        1640         201605        4      1640
# 4           201607         14        1050         201607       14      1050
#
#    EPISODE_ID  EVENT_ID      STATE  STATE_FIPS  ...  DATA_SOURCE  \
# 0      105872    635269  TENNESSEE          47  ...          CSV
# 1      105872    635264  TENNESSEE          47  ...          CSV
# 2      105872    635264  TENNESSEE          47  ...          CSV
# 3      104814    627799  TENNESSEE          47  ...          CSV
# 4      106440    638992  TENNESSEE          47  ...          CSV
#
#   FAT_YEARMONTH FAT_DAY FAT_TIME  FATALITY_ID FATALITY_TYPE  \
# ...

# %%
tn_fatalities_decade.columns
# Out:
# Index(['BEGIN_YEARMONTH', 'BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',
#        'END_DAY', 'END_TIME', 'EPISODE_ID', 'EVENT_ID', 'STATE', 'STATE_FIPS',
#        'YEAR', 'MONTH_NAME', 'EVENT_TYPE', 'CZ_TYPE', 'CZ_FIPS', 'CZ_NAME',
#        'WFO', 'BEGIN_DATE_TIME', 'CZ_TIMEZONE', 'END_DATE_TIME',
#        'INJURIES_DIRECT', 'INJURIES_INDIRECT', 'DEATHS_DIRECT',
#        'DEATHS_INDIRECT', 'DAMAGE_PROPERTY', 'DAMAGE_CROPS', 'SOURCE',
#        'MAGNITUDE', 'MAGNITUDE_TYPE', 'FLOOD_CAUSE', 'CATEGORY', 'TOR_F_SCALE',
#        'TOR_LENGTH', 'TOR_WIDTH', 'TOR_OTHER_WFO', 'TOR_OTHER_CZ_STATE',
#        'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME', 'BEGIN_RANGE',
#        'BEGIN_AZIMUTH', 'BEGIN_LOCATION', 'END_RANGE', 'END_AZIMUTH',
#        'END_LOCATION', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
#        'EPISODE_NARRATIVE', 'EVENT_NARRATIVE', 'DATA_SOURCE', 'FAT_YEARMONTH',
#        'FAT_DAY', 'FAT_TIME', 'FATALITY_ID', 'FATALITY_TYPE', 'FATALITY_DATE',
# ...

# %%
fatalities_decade.columns
# Out:
# Index(['FAT_YEARMONTH', 'FAT_DAY', 'FAT_TIME', 'FATALITY_ID', 'EVENT_ID',
#        'FATALITY_TYPE', 'FATALITY_DATE', 'FATALITY_AGE', 'FATALITY_SEX',
#        'FATALITY_LOCATION'],
#       dtype='object')

# %%
#subsetting to only include columns from the origian fatality records

tn_fatalities_decade = tn_fatalities_decade[fatalities_decade.columns]
tn_fatalities_decade.head()
# Out:
#    FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0         201607        8         0        30294    635269             D
# 1         201607        8         0        30292    635264             D
# 2         201607        8         0        30293    635264             D
# 3         201605        4         0        30198    627799             D
# 4         201607       14         0        31229    638992             D
#
#          FATALITY_DATE  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION
# 0  07/08/2016 00:00:00          66.0            F     Outside/Open Areas
# 1  07/08/2016 00:00:00          60.0            M                Camping
# 2  07/08/2016 00:00:00          47.0            F                Camping
# 3  05/04/2016 00:00:00          64.0            M  Vehicle/Towed Trailer
# 4  07/14/2016 00:00:00          65.0            F             Under Tree

# %%
#repeating the previous steps but for storm locations

locations_2016 = pd.read_csv('../noaa_data/StormEvents_locations-ftp_v1.0_d2016_c20260707.csv')
locations_2017 = pd.read_csv('../noaa_data/StormEvents_locations-ftp_v1.0_d2017_c20260707.csv')
locations_2018 = pd.read_csv('../noaa_data/StormEvents_locations-ftp_v1.0_d2018_c20260707.csv')
locations_2019 = pd.read_csv('../noaa_data/StormEvents_locations-ftp_v1.0_d2019_c20260707.csv')
locations_2020 = pd.read_csv('../noaa_data/StormEvents_locations-ftp_v1.0_d2020_c20260707.csv')
locations_2021 = pd.read_csv('../noaa_data/StormEvents_locations-ftp_v1.0_d2021_c20260707.csv')
locations_2022 = pd.read_csv('../noaa_data/StormEvents_locations-ftp_v1.0_d2022_c20260707.csv')
locations_2023 = pd.read_csv('../noaa_data/StormEvents_locations-ftp_v1.0_d2023_c20260707.csv')
locations_2024 = pd.read_csv('../noaa_data/StormEvents_locations-ftp_v1.0_d2024_c20260707.csv')
locations_2025 = pd.read_csv('../noaa_data/StormEvents_locations-ftp_v1.0_d2025_c20260707.csv')

# %%
locations_decade = pd.concat(
    [locations_2016 ,locations_2017 ,locations_2018 ,locations_2019 ,locations_2020 ,locations_2021 ,locations_2022 ,locations_2023 ,locations_2024 ,locations_2025]
)

# %%
locations_decade
# Out:
#        YEARMONTH  EPISODE_ID  EVENT_ID  LOCATION_INDEX  RANGE AZIMUTH  \
# 0         201601      102999    615391               1   0.69       S
# 1         201601      102999    615392               1   1.50     SSW
# 2         201601      102999    615393               1   0.91      NW
# 3         201601      102999    615394               1   0.69       S
# 4         201601      102999    615395               1   0.59       W
# ...          ...         ...       ...             ...    ...     ...
# 51865     202510      207217   1292889               3   1.63     NNE
# 51866     202510      207217   1292889               4   0.44     ESE
# 51867     202510      207217   1292893               1   2.48       N
# 51868     202510      207217   1292893               2   2.28     WNW
# 51869     202510      207217   1292893               3   2.69      SE
#
#             LOCATION  LATITUDE  LONGITUDE     LAT2      LON2
# 0          LEESVILLE   31.1400   -93.2700   318400   9316200
# ...

# %%
locations_decade.drop_duplicates().shape
# Out:
# (569673, 11)

# %%
locations_decade = locations_decade.reset_index(drop = True)

# %%
tn_details_decade
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 0               201607          8        1755         201607        8
# 1               201607          8        1810         201607        8
# 2               201607          8        1910         201607        8
# 3               201607          8        1840         201607        8
# 4               201607         14        1540         201607       14
# ...                ...        ...         ...            ...      ...
# 15459           202509         27        1200         202509       27
# 15460           202509         27        1035         202509       27
# 15461           202509         27        1053         202509       27
# 15462           202509         27        1145         202509       27
# 15463           202509          6         400         202509        6
#
#        END_TIME  EPISODE_ID  EVENT_ID      STATE  STATE_FIPS  ...  END_RANGE  \
# ...

# %%
#again using the tn_details csvs to subset other dataframes to only include TN records
tn_locations_decade = pd.merge(tn_details_decade,locations_decade, how = 'inner', on = ['EVENT_ID','EPISODE_ID'])
tn_locations_decade.shape
# Out:
# (14395, 60)

# %%
locations_decade.columns
# Out:
# Index(['YEARMONTH', 'EPISODE_ID', 'EVENT_ID', 'LOCATION_INDEX', 'RANGE',
#        'AZIMUTH', 'LOCATION', 'LATITUDE', 'LONGITUDE', 'LAT2', 'LON2'],
#       dtype='object')

# %%
#resetting the locations dataframe to only include the original locations columns

tn_locations_decade = tn_locations_decade[locations_decade.columns]
tn_locations_decade.head()
# Out:
#    YEARMONTH  EPISODE_ID  EVENT_ID  LOCATION_INDEX  RANGE AZIMUTH  \
# 0     201607      105872    635287               1   0.56       W
# 1     201607      105872    635296               1   1.32     WSW
# 2     201607      105872    635301               1   1.38       S
# 3     201607      105872    635299               1   0.69       N
# 4     201607      105948    635802               1   1.32     ENE
#
#          LOCATION  LATITUDE  LONGITUDE     LAT2     LON2
# 0            JENA     35.65     -84.18  3539000  8410800
# 1          PITNER     35.87     -83.77  3552200  8346200
# 2            DILL     35.56     -85.20  3533600  8512000
# 3  TELLICO PLAINS     35.38     -84.30  3522800  8418000
# 4          LOVELL     35.91     -84.13  3554600   847800

# %%
tn_fatalities_decade.head()
# Out:
#    FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0         201607        8         0        30294    635269             D
# 1         201607        8         0        30292    635264             D
# 2         201607        8         0        30293    635264             D
# 3         201605        4         0        30198    627799             D
# 4         201607       14         0        31229    638992             D
#
#          FATALITY_DATE  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION
# 0  07/08/2016 00:00:00          66.0            F     Outside/Open Areas
# 1  07/08/2016 00:00:00          60.0            M                Camping
# 2  07/08/2016 00:00:00          47.0            F                Camping
# 3  05/04/2016 00:00:00          64.0            M  Vehicle/Towed Trailer
# 4  07/14/2016 00:00:00          65.0            F             Under Tree

# %%
tn_fatalities_decade.columns
# Out:
# Index(['FAT_YEARMONTH', 'FAT_DAY', 'FAT_TIME', 'FATALITY_ID', 'EVENT_ID',
#        'FATALITY_TYPE', 'FATALITY_DATE', 'FATALITY_AGE', 'FATALITY_SEX',
#        'FATALITY_LOCATION'],
#       dtype='object')

# %%
tn_fatalities_decade['FAT_TIME'].drop(columns = 'FAT_TIME')
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 200    0
# 201    0
# 202    0
# 203    0
# 204    0
# Name: FAT_TIME, Length: 205, dtype: int64

# %%
tn_fatalities_decade.to_csv(r'C:\Users\plann\Documents\Nashville Software School\Python\Capstone\TN_storms\python_cleaning\tn_fatalities_decade.csv',index = False)

# %%
print(os.getcwd())  # Displays the full folder path
# Out:
# C:\Users\plann\Documents\Nashville Software School\Python\Capstone\TN_storms\python_cleaning

# %%
tn_fatalities_decade
# Out:
#      FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0           201607        8         0        30294    635269             D
# 1           201607        8         0        30292    635264             D
# 2           201607        8         0        30293    635264             D
# 3           201605        4         0        30198    627799             D
# 4           201607       14         0        31229    638992             D
# ..             ...      ...       ...          ...       ...           ...
# 200         202507       21         0        59550   1283432             D
# 201         202508       12         0        59517   1283123             D
# 202         202508       12         0        59518   1283123             D
# 203         202508       12         0        59519   1283123             D
# 204         202508       12         0        59815   1287783             D
#
# ...

# %%
tn_locations_decade.to_csv(r'C:\Users\plann\Documents\Nashville Software School\Python\Capstone\TN_storms\python_cleaning\tn_locations_decade.csv',index = False)

# %%
tn_locations_decade.head()
# Out:
#    YEARMONTH  EPISODE_ID  EVENT_ID  LOCATION_INDEX  RANGE AZIMUTH  \
# 0     201607      105872    635287               1   0.56       W
# 1     201607      105872    635296               1   1.32     WSW
# 2     201607      105872    635301               1   1.38       S
# 3     201607      105872    635299               1   0.69       N
# 4     201607      105948    635802               1   1.32     ENE
#
#          LOCATION  LATITUDE  LONGITUDE     LAT2     LON2
# 0            JENA     35.65     -84.18  3539000  8410800
# 1          PITNER     35.87     -83.77  3552200  8346200
# 2            DILL     35.56     -85.20  3533600  8512000
# 3  TELLICO PLAINS     35.38     -84.30  3522800  8418000
# 4          LOVELL     35.91     -84.13  3554600   847800

# %%
tn_details_decade.to_csv(r'C:\Users\plann\Documents\Nashville Software School\Python\Capstone\TN_storms\python_cleaning\tn_details_decade.csv',index = False)
