# %%
import pandas as pd
import regex as re
import sqlalchemy as sqla
import numpy as np
from IPython.display import HTML

# %%
details_regex = pd.read_csv('details_cleaned.csv')
details_regex
# Out:
#       BEGIN_DATE BEGIN_TIME   END_DATE  END_TIME  EPISODE_ID  EVENT_ID  \
# 0      08-JUL-16   17:55:00  08-JUL-16  17:55:00      105872    635287
# 1      08-JUL-16   18:10:00  08-JUL-16  18:10:00      105872    635296
# 2      08-JUL-16   19:10:00  08-JUL-16  19:10:00      105872    635301
# 3      08-JUL-16   18:40:00  08-JUL-16  18:40:00      105872    635299
# 4      14-JUL-16   15:40:00  14-JUL-16  15:40:00      105948    635802
# ...          ...        ...        ...       ...         ...       ...
# 15459  27-SEP-25   12:00:00  27-SEP-25  14:00:00      207597   1294715
# 15460  27-SEP-25   10:35:00  27-SEP-25  12:35:00      207597   1294716
# 15461  27-SEP-25   10:53:00  27-SEP-25  12:53:00      207597   1294717
# 15462  27-SEP-25   11:45:00  27-SEP-25  13:45:00      207597   1294718
# 15463  06-SEP-25   04:00:00  06-SEP-25  04:35:00      207573   1294606
#
#               EVENT_TYPE CZ_TYPE  CZ_FIPS  CZ_NAME  ...  BEGIN_LOCATION  \
# ...

# %%
regex_narratives = details_regex[['EPISODE_ID','EVENT_ID','EPISODE_NARRATIVE','EVENT_NARRATIVE']]
regex_narratives
# Out:
#        EPISODE_ID  EVENT_ID  \
# 0          105872    635287
# 1          105872    635296
# 2          105872    635301
# 3          105872    635299
# 4          105948    635802
# ...           ...       ...
# 15459      207597   1294715
# 15460      207597   1294716
# 15461      207597   1294717
# 15462      207597   1294718
# 15463      207573   1294606
#
#                                        EPISODE_NARRATIVE  \
# 0      The combination of summer heating and high low...
# 1      The combination of summer heating and high low...
# 2      The combination of summer heating and high low...
# 3      The combination of summer heating and high low...
# 4      An organized area of thunderstorms moved into ...
# ...                                                  ...
# 15459  Numerous showers and thunderstorms developing ...
# 15460  Numerous showers and thunderstorms developing ...
# 15461  Numerous showers and thunderstorms developing ...
# ...

# %%
regex_narratives.to_csv(r'C:\Users\plann\Documents\Nashville Software School\Python\Capstone\TN_storms\python_cleaning\regex_narratives.csv',index = False)

# %%
regex_csv = pd.read_csv('regex_narratives.csv')
regex_csv
# Out:
#        EPISODE_ID  EVENT_ID  \
# 0          105872    635287
# 1          105872    635296
# 2          105872    635301
# 3          105872    635299
# 4          105948    635802
# ...           ...       ...
# 15459      207597   1294715
# 15460      207597   1294716
# 15461      207597   1294717
# 15462      207597   1294718
# 15463      207573   1294606
#
#                                        EPISODE_NARRATIVE  \
# 0      The combination of summer heating and high low...
# 1      The combination of summer heating and high low...
# 2      The combination of summer heating and high low...
# 3      The combination of summer heating and high low...
# 4      An organized area of thunderstorms moved into ...
# ...                                                  ...
# 15459  Numerous showers and thunderstorms developing ...
# 15460  Numerous showers and thunderstorms developing ...
# 15461  Numerous showers and thunderstorms developing ...
# ...

# %%
regex_csv.loc[regex_csv['EVENT_NARRATIVE'].fillna('').str.contains('road')]
# Out:
#        EPISODE_ID  EVENT_ID  \
# 24         102861    614749
# 139        103131    616290
# 150        103132    616662
# 151        103132    616664
# 169        103132    616666
# ...           ...       ...
# 15321      208339   1304256
# 15351      207510   1294315
# 15354      207510   1294318
# 15370      205399   1281396
# 15427      205662   1283236
#
#                                        EPISODE_NARRATIVE  \
# 24     A weak area of low pressure moved northeast al...
# 139    A strong but fast moving winter storm pushed r...
# 150    A powerful upper level low pressure system mov...
# 151    A powerful upper level low pressure system mov...
# 169    A powerful upper level low pressure system mov...
# ...                                                  ...
# 15321  A broken line of showers and strong to severe ...
# 15351  A line of showers and thunderstorms moved acro...
# 15354  A line of showers and thunderstorms moved acro...
# ...

# %%
event_narrative = regex_csv[['EVENT_ID','EVENT_NARRATIVE',]]
event_narrative
# Out:
#        EVENT_ID                                    EVENT_NARRATIVE
# 0        635287  Numerous trees were reported down in the Green...
# 1        635296  Numerous trees were reported down in Seymour. ...
# 2        635301  Several trees were reported down across the so...
# 3        635299  A few trees were reported down one mile north ...
# 4        635802             Ping pong ball size hail was reported.
# ...         ...                                                ...
# 15459   1294715  Social media video showed a small stream out o...
# 15460   1294716  Ridge Road, just south of the Sevier County So...
# 15461   1294717  A spotter reported 4 inches of water crossing ...
# 15462   1294718  Burden Hill Road at Eastgate Road is closed du...
# 15463   1294606  A severe thunderstorm produced a swath of inte...
#
# [15464 rows x 2 columns]

# %%
regex_csv[['EPISODE_ID','EVENT_NARRATIVE']].loc[regex_csv['EVENT_NARRATIVE'].fillna('').str.contains('road')].reset_index(drop=True)
# Out:
#       EPISODE_ID                                    EVENT_NARRATIVE
# 0         102861  A quarter of an inch of freezing rain accumula...
# 1         103131  A mix of light sleet, freezing rain, and snow ...
# 2         103132  Freezing rain amounts up to 1/4 of an inch fel...
# 3         103132  Freezing rain amounts up to 1/4 of an inch fel...
# 4         103132  Freezing rain amounts up to 1/4 of an inch fel...
# ...          ...                                                ...
# 1339      208339  Trees were reported down near the intersection...
# 1340      207510  Severe thunderstorm winds downed numerous tree...
# 1341      207510  Estimated 60 mph winds were reported in the Be...
# 1342      205399  Severe thunderstorm winds downed a tree on Cyp...
# 1343      205662  A large tree was blown down across the road by...
#
# [1344 rows x 2 columns]

# %%
regex_csv[['EPISODE_ID','EVENT_NARRATIVE']].loc[regex_csv['EVENT_NARRATIVE'].fillna('').str.contains('tree')].reset_index(drop=True)
# Out:
#       EPISODE_ID                                    EVENT_NARRATIVE
# 0         105872  Numerous trees were reported down in the Green...
# 1         105872  Numerous trees were reported down in Seymour. ...
# 2         105872  Several trees were reported down across the so...
# 3         105872  A few trees were reported down one mile north ...
# 4         105948  A tree fell onto a car four miles west southwe...
# ...          ...                                                ...
# 5564      205662  Several trees were blown down by severe thunde...
# 5565      205662  A large tree was blown down onto powerlines by...
# 5566      205662  Several trees were blown down around Mooresbur...
# 5567      205662  Multiple large tree limbs were broken off the ...
# 5568      207573  A severe thunderstorm produced a swath of inte...
#
# [5569 rows x 2 columns]

# %%
regex_csv[['EPISODE_ID','EVENT_NARRATIVE']].loc[regex_csv['EVENT_NARRATIVE'].fillna('').str.contains('highway')].reset_index(drop=True)
# Out:
#     EPISODE_ID                                    EVENT_NARRATIVE
# 0       105872  Numerous trees were reported down in Seymour. ...
# 1       105869  A few trees were reported down along highway 1...
# 2       105869  A large tree was reported down along highway 2...
# 3       102691            A tree was reported down on highway 58.
# 4       105872  Several trees were downed along highway 62 two...
# 5       105836  A few trees were reported down in the vicinity...
# 6       105836  Several trees were reported down along highway...
# 7       110978  Structural damage was reported to several buil...
# 8       114822  Significant damage was reported at the Poplar ...
# 9       113450  National Weather Service personnel along with ...
# 10      114118  An EF-1 tornado touched down along Hillsboro R...
# 11      114735  Public reported hail of golf ball size with a ...
# 12      114683  The roof of a large barn was blown off on High...
# ...

# %%
regex_csv[['EPISODE_ID','EVENT_NARRATIVE']].loc[regex_csv['EVENT_NARRATIVE'].fillna('').str.contains('I-')].reset_index(drop=True)
# Out:
#      EPISODE_ID                                    EVENT_NARRATIVE
# 0        105914  A metal awning connected to the front of a bui...
# 1        103132  Freezing rain amounts up to 1/4 of an inch fel...
# 2        103132  Freezing rain amounts up to 1/4 of an inch fel...
# 3        103132  Freezing rain amounts up to 1/4 of an inch fel...
# 4        103131  A mix of light sleet, freezing rain and up to ...
# ..          ...                                                ...
# 164      202201  A foot of water covered I-40 near Danny Thomas...
# 165      201973      Quarter sized hail at mile marker 93 on I-40.
# 166      201973  Quarter sized hail south of I-40 and the 45 by...
# 167      201973                      Quarter sized hail near I-40.
# 168      201973  Water covering up to 2 lanes on I-40 east boun...
#
# [169 rows x 2 columns]

# %%
regex_csv[['EPISODE_ID','EVENT_NARRATIVE']].loc[regex_csv['EVENT_NARRATIVE'].fillna('').str.contains('outage')].reset_index(drop=True)
# Out:
#      EPISODE_ID                                    EVENT_NARRATIVE
# 0        103132  Freezing rain amounts up to 1/4 of an inch fel...
# 1        103132  Freezing rain amounts up to 1/4 of an inch fel...
# 2        103132  Freezing rain amounts up to 1/4 of an inch fel...
# 3        103132  Freezing rain amounts up to 1/3 of an inch fel...
# 4        103132  Freezing rain amounts up to 1/4 of an inch fel...
# ..          ...                                                ...
# 241      199614  Severe thunderstorm winds caused power outages...
# 242      203044  Numerous trees were blown down by severe thund...
# 243      204133  Several trees were blown down by severe thunde...
# 244      203047  Couple dozen medium to large trees were blown ...
# 245      208278  Mesonet measured 60 mph in Dover and 50 mph in...
#
# [246 rows x 2 columns]

# %%
pd.options.display.max_colwidth = 2000

# %%
regex_csv[['EVENT_ID','EVENT_NARRATIVE']].loc[regex_csv['EVENT_NARRATIVE'].fillna('').str.contains('school')].reset_index(drop=True).count()
# Out:
# EVENT_ID           45
# EVENT_NARRATIVE    45
# dtype: int64

# %%
pd.options.display.max_colwidth = 50
details_cleaned = pd.read_csv('details_cleaned.csv')

# %%
details_cleaned
# Out:
#       BEGIN_DATE BEGIN_TIME   END_DATE  END_TIME  EPISODE_ID  EVENT_ID  \
# 0      08-JUL-16   17:55:00  08-JUL-16  17:55:00      105872    635287
# 1      08-JUL-16   18:10:00  08-JUL-16  18:10:00      105872    635296
# 2      08-JUL-16   19:10:00  08-JUL-16  19:10:00      105872    635301
# 3      08-JUL-16   18:40:00  08-JUL-16  18:40:00      105872    635299
# 4      14-JUL-16   15:40:00  14-JUL-16  15:40:00      105948    635802
# ...          ...        ...        ...       ...         ...       ...
# 15459  27-SEP-25   12:00:00  27-SEP-25  14:00:00      207597   1294715
# 15460  27-SEP-25   10:35:00  27-SEP-25  12:35:00      207597   1294716
# 15461  27-SEP-25   10:53:00  27-SEP-25  12:53:00      207597   1294717
# 15462  27-SEP-25   11:45:00  27-SEP-25  13:45:00      207597   1294718
# 15463  06-SEP-25   04:00:00  06-SEP-25  04:35:00      207573   1294606
#
#               EVENT_TYPE CZ_TYPE  CZ_FIPS  CZ_NAME  ...  BEGIN_LOCATION  \
# ...

# %%
details_cleaned['CZ_NAME'].unique()
# Out:
# array(['LOUDON', 'SEVIER', 'BLEDSOE', 'MONROE', 'KNOX', 'MCMINN',
#        'GREENE', 'DAVIDSON', 'HUMPHREYS', 'MONTGOMERY', 'COCKE', 'MARION',
#        'CHEATHAM', 'DEKALB', 'FRANKLIN', 'DICKSON', 'WARREN', 'LINCOLN',
#        'MOORE', 'WILSON', 'SUMNER', 'CAMPBELL', 'SOUTHEAST CARTER',
#        'COCKE/SMOKY MOUNTAINS', 'NORTHWEST COCKE', 'HAMBLEN', 'JOHNSON',
#        'MORGAN', 'SCOTT', 'NORTH SEVIER', 'SULLIVAN', 'UNICOI',
#        'WASHINGTON', 'HAWKINS', 'ROANE', 'ANDERSON', 'CLAIBORNE',
#        'JEFFERSON', 'NORTHWEST CARTER', 'NORTHWEST BLOUNT', 'GRAINGER',
#        'NORTHWEST GREENE', 'SEQUATCHIE', 'CLAY', 'FENTRESS', 'OVERTON',
#        'HARDEMAN', 'FAYETTE', 'MCNAIRY', 'SHELBY', 'TIPTON', 'SMITH',
#        'MACON', 'ROBERTSON', 'STEWART', 'WHITE', 'UNION', 'PUTNAM',
#        'CUMBERLAND', 'SOUTHEAST GREENE', 'NORTHWEST MONROE', 'HAMILTON',
#        'CARTER', 'PICKETT', 'COFFEE', 'WILLIAMSON', 'MAURY', 'VAN BUREN',
# ...

# %%
details_cleaned['CZ_NAME'] = details_cleaned['CZ_NAME'].str.replace('/SMOKY MOUNTAINS','').str.replace('NORTHWEST ','').str.replace('SOUTHEAST ', '').str.replace('EAST ','').str.replace('NORTH ', '').str.replace('WEST', '').str.replace('SOUTH ','').str.replace(' POLK','POLK')

# %%
#details_cleaned.groupby('CZ_NAME')
len(regex_csv[['EPISODE_ID','EVENT_NARRATIVE']].loc[regex_csv['EVENT_NARRATIVE'].fillna('').str.contains('outage')])
# Out:
# 246

# %%
road_str = details_cleaned.loc[details_cleaned['EVENT_NARRATIVE'].fillna('').str.contains('road')].groupby('CZ_NAME').count()

# %%
road_str[['EVENT_NARRATIVE']].sort_values(by = 'EVENT_NARRATIVE',ascending = False)
# Out:
#           EVENT_NARRATIVE
# CZ_NAME
# LINCOLN                87
# WILSON                 77
# KNOX                   49
# DAVIDSON               44
# SHELBY                 41
# ...                   ...
# HANCOCK                 3
# GRAINGER                3
# LAKE                    3
# PICKETT                 2
# LOUDON                  2
#
# [95 rows x 1 columns]
