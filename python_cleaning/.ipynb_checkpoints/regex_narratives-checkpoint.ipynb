# %%
import pandas as pd
import regex as re
import sqlalchemy as sqla
import numpy as np
from IPython.display import HTML

# %% [markdown]
# ## need to check regex script for negative events and remove trees and home damages since I have property damages. Next I need to create severity score

# %%
details_cleaned = pd.read_csv('details_cleaned.csv')

# %%
details_cleaned
# Out:
#       BEGIN_DATE BEGIN_TIME   END_DATE  END_TIME  EPISODE_ID  EVENT_ID  \
# 0      08-JUL-16   17:55:00  08-JUL-16  17:55:00      105872    635287
# 1      08-JUL-16   18:10:00  08-JUL-16  18:10:00      105872    635296
# 2      08-JUL-16   19:10:00  08-JUL-16  19:10:00      105872    635301
# 3      08-JUL-16   18:40:00  08-JUL-16  18:40:00      105872    635299
# 4      14-JUL-16   15:40:00  14-JUL-16  15:40:00      105948    635802
# ...          ...        ...        ...       ...         ...       ...
# 15459  27-SEP-25   12:00:00  27-SEP-25  14:00:00      207597   1294715
# 15460  27-SEP-25   10:35:00  27-SEP-25  12:35:00      207597   1294716
# 15461  27-SEP-25   10:53:00  27-SEP-25  12:53:00      207597   1294717
# 15462  27-SEP-25   11:45:00  27-SEP-25  13:45:00      207597   1294718
# 15463  06-SEP-25   04:00:00  06-SEP-25  04:35:00      207573   1294606
#
#               EVENT_TYPE CZ_TYPE  CZ_FIPS  CZ_NAME  ...    END_LOCATION  \
# ...

# %%
details_cleaned['CZ_NAME'].unique()
# Out:
# array(['LOUDON', 'SEVIER', 'BLEDSOE', 'MONROE', 'KNOX', 'MCMINN',
#        'GREENE', 'DAVIDSON', 'HUMPHREYS', 'MONTGOMERY', 'COCKE', 'MARION',
#        'CHEATHAM', 'DEKALB', 'FRANKLIN', 'DICKSON', 'WARREN', 'LINCOLN',
#        'MOORE', 'WILSON', 'SUMNER', 'CAMPBELL', 'CARTER', 'HAMBLEN',
#        'JOHNSON', 'MORGAN', 'SCOTT', 'SULLIVAN', 'UNICOI', 'WASHINGTON',
#        'HAWKINS', 'ROANE', 'ANDERSON', 'CLAIBORNE', 'JEFFERSON', 'BLOUNT',
#        'GRAINGER', 'SEQUATCHIE', 'CLAY', 'FENTRESS', 'OVERTON',
#        'HARDEMAN', 'FAYETTE', 'MCNAIRY', 'SHELBY', 'TIPTON', 'SMITH',
#        'MACON', 'ROBERTSON', 'STEWART', 'WHITE', 'UNION', 'PUTNAM',
#        'CUMBERLAND', 'HAMILTON', 'PICKETT', 'COFFEE', 'WILLIAMSON',
#        'MAURY', 'VAN BUREN', 'CANNON', 'MARSHALL', 'BEDFORD', 'HOUSTON',
#        'HARDIN', 'MEIGS', 'GRUNDY', 'GILES', 'PERRY', 'WAYNE', 'LEWIS',
#        'LAWRENCE', 'CROCKETT', 'DYER', 'GIBSON', 'MADISON', 'RHEA',
# ...

# %%
details_cleaned['CZ_NAME'] = details_cleaned['CZ_NAME'].str.replace('/SMOKY MOUNTAINS','').str.replace('NORTHWEST ','').str.replace('SOUTHEAST ', '').str.replace('EAST ','').str.replace('NORTH ', '').str.replace('WEST', '').str.replace('SOUTH ','').str.replace(' POLK','POLK')

# %%
details_cleaned
# Out:
#       BEGIN_DATE BEGIN_TIME   END_DATE  END_TIME  EPISODE_ID  EVENT_ID  \
# 0      08-JUL-16   17:55:00  08-JUL-16  17:55:00      105872    635287
# 1      08-JUL-16   18:10:00  08-JUL-16  18:10:00      105872    635296
# 2      08-JUL-16   19:10:00  08-JUL-16  19:10:00      105872    635301
# 3      08-JUL-16   18:40:00  08-JUL-16  18:40:00      105872    635299
# 4      14-JUL-16   15:40:00  14-JUL-16  15:40:00      105948    635802
# ...          ...        ...        ...       ...         ...       ...
# 15459  27-SEP-25   12:00:00  27-SEP-25  14:00:00      207597   1294715
# 15460  27-SEP-25   10:35:00  27-SEP-25  12:35:00      207597   1294716
# 15461  27-SEP-25   10:53:00  27-SEP-25  12:53:00      207597   1294717
# 15462  27-SEP-25   11:45:00  27-SEP-25  13:45:00      207597   1294718
# 15463  06-SEP-25   04:00:00  06-SEP-25  04:35:00      207573   1294606
#
#               EVENT_TYPE CZ_TYPE  CZ_FIPS  CZ_NAME  ...    END_LOCATION  \
# ...

# %%
text = details_cleaned['EVENT_NARRATIVE'].astype(str).str.lower()

from collections import Counter

stopwords = {'the','a','an','of','and','or','to','in','on','at','was','were',
             'is','are','be','been','with','by','from','as','it','this','that'}

counter = Counter()
for t in text:
    words = re.findall(r"[a-z']+",t)
    for w in words:
        if w not in stopwords:
             counter[w] += 1

word_count = pd.DataFrame(counter.most_common(325), columns=['word','count'])
word_count
# Out:
#          word  count
# 0        road   5812
# 1        down   5185
# 2       trees   4831
# 3      county   4222
# 4        snow   3634
# ..        ...    ...
# 320  powerful    108
# 321     smith    107
# 322  included    107
# 323    couple    106
# 324     tower    105
#
# [325 rows x 2 columns]

# %%
# import pandas as pd
# import re
# from collections import Counter

# df = pd.read_csv('details_cleaned.csv')
# text = df['EVENT_NARRATIVE'].dropna().astype(str).str.lower()

# stopwords = {'the','a','an','of','and','or','to','in','on','at','was','were',
#              'is','are','be','been','with','by','from','as','it','this','that'}

# counter = Counter()
# for t in text:
#     words = re.findall(r"[a-z']+", t)
#     counter.update(w for w in words if w not in stopwords and len(w) > 2)

# word_count = pd.DataFrame(counter.most_common(325), columns=['word','count'])
# word_count

# %%
def row_display(x):
    pd.options.display.max_rows = x

# %%
def row_default():
    pd.options.display.max_rows = 60

# %%
row_display(325)
word_count
# Out:
#              word  count
# 0            road   5812
# 1            down   5185
# 2           trees   4831
# 3          county   4222
# 4            snow   3634
# 5          inches   3460
# 6          across   3280
# 7           blown   3021
# 8        reported   2791
# 9            tree   2720
# 10           near   2214
# 11       measured   2200
# 12        several   2076
# 13        degrees   1981
# 14           fell   1931
# 15         damage   1920
# 16           heat   1817
# 17         severe   1767
# 18        highway   1611
# 19          along   1539
# 20          winds   1534
# 21        tornado   1534
# 22          power   1522
# 23        station   1497
# 24          index   1481
# 25   thunderstorm   1406
# 26       cocorahs   1332
# 27        damages   1150
# 28     conditions   1132
# 29           wind   1117
# 30        drought   1035
# 31           hail   1034
# 32          large    999
# 33             up    992
# 34           area    959
# 35      estimated    954
# ...

# %%
row_default()

# %%
details_cleaned.head()
# Out:
#   BEGIN_DATE BEGIN_TIME   END_DATE  END_TIME  EPISODE_ID  EVENT_ID  \
# 0  08-JUL-16   17:55:00  08-JUL-16  17:55:00      105872    635287
# 1  08-JUL-16   18:10:00  08-JUL-16  18:10:00      105872    635296
# 2  08-JUL-16   19:10:00  08-JUL-16  19:10:00      105872    635301
# 3  08-JUL-16   18:40:00  08-JUL-16  18:40:00      105872    635299
# 4  14-JUL-16   15:40:00  14-JUL-16  15:40:00      105948    635802
#
#           EVENT_TYPE CZ_TYPE  CZ_FIPS  CZ_NAME  ...    END_LOCATION BEGIN_LAT  \
# 0  Thunderstorm Wind       C      105   LOUDON  ...            JENA     35.65
# 1  Thunderstorm Wind       C      155   SEVIER  ...          PITNER     35.87
# 2  Thunderstorm Wind       C        7  BLEDSOE  ...            DILL     35.56
# 3  Thunderstorm Wind       C      123   MONROE  ...  TELLICO PLAINS     35.38
# 4               Hail       C       93     KNOX  ...          LOVELL     35.91
#
#    BEGIN_LON  END_LAT  END_LON  \
# 0     -84.18    35.65   -84.18
# ...

# %%
row_display(325)
word_count
# Out:
#              word  count
# 0            road   5812
# 1            down   5185
# 2           trees   4831
# 3          county   4222
# 4            snow   3634
# 5          inches   3460
# 6          across   3280
# 7           blown   3021
# 8        reported   2791
# 9            tree   2720
# 10           near   2214
# 11       measured   2200
# 12        several   2076
# 13        degrees   1981
# 14           fell   1931
# 15         damage   1920
# 16           heat   1817
# 17         severe   1767
# 18        highway   1611
# 19          along   1539
# 20          winds   1534
# 21        tornado   1534
# 22          power   1522
# 23        station   1497
# 24          index   1481
# 25   thunderstorm   1406
# 26       cocorahs   1332
# 27        damages   1150
# 28     conditions   1132
# 29           wind   1117
# 30        drought   1035
# 31           hail   1034
# 32          large    999
# 33             up    992
# 34           area    959
# 35      estimated    954
# ...

# %%
details_cleaned['road_closures'] = details_cleaned['EVENT_NARRATIVE'].astype(str).str.contains(r'(?i)(?=\S*.(road|sr-|highway|i-|lane|rd.))(?=.*(closed|blocked|flooded|closure))')
details_cleaned
# Out:
# C:\Users\plann\AppData\Local\Temp\ipykernel_48268\3786352316.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   details_cleaned['road_closures'] = details_cleaned['EVENT_NARRATIVE'].astype(str).str.contains(r'(?i)(?=\S*.(road|sr-|highway|i-|lane|rd.))(?=.*(closed|blocked|flooded|closure|close))')
#       BEGIN_DATE BEGIN_TIME   END_DATE  END_TIME  EPISODE_ID  EVENT_ID  \
# 0      08-JUL-16   17:55:00  08-JUL-16  17:55:00      105872    635287
# 1      08-JUL-16   18:10:00  08-JUL-16  18:10:00      105872    635296
# 2      08-JUL-16   19:10:00  08-JUL-16  19:10:00      105872    635301
# 3      08-JUL-16   18:40:00  08-JUL-16  18:40:00      105872    635299
# 4      14-JUL-16   15:40:00  14-JUL-16  15:40:00      105948    635802
# ...          ...        ...        ...       ...         ...       ...
# 15459  27-SEP-25   12:00:00  27-SEP-25  14:00:00      207597   1294715
# ...

# %%
details_cleaned.loc[details_cleaned['road_closures'] == True]
# Out:
#       BEGIN_DATE BEGIN_TIME   END_DATE  END_TIME  EPISODE_ID  EVENT_ID  \
# 150    21-JAN-16   21:00:00  23-JAN-16  00:00:00      103132    616662
# 151    21-JAN-16   21:00:00  23-JAN-16  10:00:00      103132    616664
# 169    21-JAN-16   21:00:00  23-JAN-16  10:00:00      103132    616666
# 179    24-FEB-16   12:00:00  24-FEB-16  12:00:00      103313    617472
# 196    20-JAN-16   00:00:00  20-JAN-16  12:00:00      103131    616388
# ...          ...        ...        ...       ...         ...       ...
# 15351  07-NOV-25   16:05:00  07-NOV-25  16:05:00      207510   1294315
# 15370  05-SEP-25   16:20:00  05-SEP-25  16:20:00      205399   1281396
# 15460  27-SEP-25   10:35:00  27-SEP-25  12:35:00      207597   1294716
# 15462  27-SEP-25   11:45:00  27-SEP-25  13:45:00      207597   1294718
# 15463  06-SEP-25   04:00:00  06-SEP-25  04:35:00      207573   1294606
#
#               EVENT_TYPE CZ_TYPE  CZ_FIPS     CZ_NAME  ... END_LOCATION  \
# ...

# %%
details_cleaned['power_outage'] = details_cleaned['EVENT_NARRATIVE'].str.contains(r'(?i)(?=.*(power|line))(?=.*(outage|lost|down|damaged))')
details_cleaned
# Out:
# C:\Users\plann\AppData\Local\Temp\ipykernel_48268\2922760017.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   details_cleaned['power_outage'] = details_cleaned['EVENT_NARRATIVE'].str.contains(r'(?i)(?=.*(power|line))(?=.*(outage|lost|down|damaged))')
#       BEGIN_DATE BEGIN_TIME   END_DATE  END_TIME  EPISODE_ID  EVENT_ID  \
# 0      08-JUL-16   17:55:00  08-JUL-16  17:55:00      105872    635287
# 1      08-JUL-16   18:10:00  08-JUL-16  18:10:00      105872    635296
# 2      08-JUL-16   19:10:00  08-JUL-16  19:10:00      105872    635301
# 3      08-JUL-16   18:40:00  08-JUL-16  18:40:00      105872    635299
# 4      14-JUL-16   15:40:00  14-JUL-16  15:40:00      105948    635802
# ...          ...        ...        ...       ...         ...       ...
# 15459  27-SEP-25   12:00:00  27-SEP-25  14:00:00      207597   1294715
# ...

# %%
details_cleaned.loc[details_cleaned['power_outage'] == True]
# Out:
#       BEGIN_DATE BEGIN_TIME   END_DATE  END_TIME  EPISODE_ID  EVENT_ID  \
# 38     15-JUN-16   17:05:00  15-JUN-16  17:08:00      105138    640639
# 135    24-FEB-16   07:30:00  24-FEB-16  07:30:00      103313    617419
# 144    24-FEB-16   08:40:00  24-FEB-16  08:40:00      103313    617425
# 145    24-FEB-16   08:40:00  24-FEB-16  08:40:00      103313    617427
# 150    21-JAN-16   21:00:00  23-JAN-16  00:00:00      103132    616662
# ...          ...        ...        ...       ...         ...       ...
# 15451  04-SEP-25   11:30:00  04-SEP-25  11:30:00      205662   1283230
# 15452  04-SEP-25   11:55:00  04-SEP-25  11:55:00      205662   1283231
# 15453  04-SEP-25   12:00:00  04-SEP-25  12:00:00      205662   1283232
# 15456  04-SEP-25   13:45:00  04-SEP-25  13:45:00      205662   1283235
# 15463  06-SEP-25   04:00:00  06-SEP-25  04:35:00      207573   1294606
#
#               EVENT_TYPE CZ_TYPE  CZ_FIPS     CZ_NAME  ...    END_LOCATION  \
# ...

# %%
details_cleaned['tree_damage'] = details_cleaned['EVENT_NARRATIVE'].str.contains(r'(?i)(?=.*(tree))(?=.*(broke|crashed))')
details_cleaned
# Out:
# C:\Users\plann\AppData\Local\Temp\ipykernel_48268\3661628308.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   details_cleaned['tree_damage'] = details_cleaned['EVENT_NARRATIVE'].str.contains(r'(?i)(?=.*(tree))(?=.*(broke|crashed))')
#       BEGIN_DATE BEGIN_TIME   END_DATE  END_TIME  EPISODE_ID  EVENT_ID  \
# 0      08-JUL-16   17:55:00  08-JUL-16  17:55:00      105872    635287
# 1      08-JUL-16   18:10:00  08-JUL-16  18:10:00      105872    635296
# 2      08-JUL-16   19:10:00  08-JUL-16  19:10:00      105872    635301
# 3      08-JUL-16   18:40:00  08-JUL-16  18:40:00      105872    635299
# 4      14-JUL-16   15:40:00  14-JUL-16  15:40:00      105948    635802
# ...          ...        ...        ...       ...         ...       ...
# 15459  27-SEP-25   12:00:00  27-SEP-25  14:00:00      207597   1294715
# 15460  27-SEP-25   10:35:00  27-SEP-25  12:35:00      207597   1294716
# ...

# %%
pd.options.display.max_colwidth = 2000
details_cleaned['EVENT_NARRATIVE'].loc[details_cleaned['tree_damage'] == True]
# Out:
# 544                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
# ...

# %%
len(details_cleaned['EVENT_NARRATIVE'].loc[details_cleaned['tree_damage'] == True])
# Out:
# 105

# %%
details_cleaned.to_csv(r'C:\Users\plann\Documents\Nashville Software School\Python\Capstone\TN_storms\python_cleaning\details_cleaned.csv',index = False)

# %%
from sqlalchemy import create_engine, text

# %%
database_name = 'Capstone'    # Fill this in with your lahman database name

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}" #creates a dynamic string based on any input

# %%
engine = create_engine(connection_string)

# %%
pd.options.display.max_colwidth = 50

# %%
query = '''SELECT 
	cz_name
	,COUNT(road_closures) AS road_closures
FROM storms
WHERE road_closures = 'True'
GROUP BY cz_name
ORDER BY road_closures DESC'''

with engine.connect() as connection:
    road_closures = pd.read_sql(text(query), con = connection)

road_closures
# Out:
#        cz_name  road_closures
# 0       WILSON             54
# 1     LAWRENCE             49
# 2     DAVIDSON             44
# 3        MAURY             38
# 4   WILLIAMSON             36
# 5       SUMNER             35
# 6       SHELBY             33
# 7       SEVIER             31
# 8      DICKSON             28
# 9         KNOX             24
# 10   ROBERTSON             21
# 11    CHEATHAM             20
# 12  RUTHERFORD             19
# 13      PUTNAM             19
# 14    HAMILTON             18
# 15  MONTGOMERY             18
# 16      GRUNDY             18
# 17      TIPTON             16
# 18     MADISON             16
# 19    CROCKETT             16
# 20  CUMBERLAND             15
# 21      BLOUNT             15
# 22     OVERTON             15
# 23      GREENE             14
# 24     STEWART             14
# 25      COFFEE             14
# 26     JACKSON             13
# 27     HICKMAN             12
# 28       MACON             12
# 29       GILES             12
# ...

# %%
query = '''SELECT 
	cz_name
	,COUNT(tree_damage) AS tree_damage
FROM storms
WHERE tree_damage = 'True'
GROUP BY cz_name
ORDER BY tree_damage DESC'''

with engine.connect() as connection:
    tree_damage = pd.read_sql(text(query), con = connection)

tree_damage.head()
# Out:
#     cz_name  tree_damage
# 0    TIPTON            6
# 1  DAVIDSON            5
# 2    SHELBY            5
# 3   LINCOLN            4
# 4   FAYETTE            4

# %%
query = '''SELECT 
	cz_name
	,COUNT(power_outage) AS power_outage
FROM storms
WHERE power_outage = 'True'
GROUP BY cz_name
ORDER BY power_outage DESC'''

with engine.connect() as connection:
    power_outage = pd.read_sql(text(query), con = connection)

power_outage.head()
# Out:
#      cz_name  power_outage
# 0   DAVIDSON            92
# 1   LAWRENCE            61
# 2     WILSON            53
# 3  ROBERTSON            47
# 4   HAMILTON            47

# %%
tree_outage = pd.merge(power_outage,tree_damage, how = 'inner', on = 'cz_name')
tree_outage_closures = pd.merge(tree_outage,road_closures, how = 'inner', on = 'cz_name')
tree_outage_closures.head()
# Out:
#      cz_name  power_outage  tree_damage  road_closures
# 0   DAVIDSON            92            5             44
# 1     WILSON            53            2             54
# 2  ROBERTSON            47            1             21
# 3       KNOX            45            1             24
# 4     SHELBY            44            5             33

# %%
tree_outage_closures['damage_score'] = tree_outage_closures['power_outage']+tree_outage_closures['tree_damage']+tree_outage_closures['road_closures']
tree_outage_closures.sort_values(by = 'damage_score',ascending = False)
# Out:
#        cz_name  power_outage  tree_damage  road_closures  damage_score
# 0     DAVIDSON            92            5             44           141
# 1       WILSON            53            2             54           109
# 4       SHELBY            44            5             33            82
# 6       SUMNER            38            3             35            76
# 8   WILLIAMSON            33            4             36            73
# 3         KNOX            45            1             24            70
# 2    ROBERTSON            47            1             21            69
# 12       MAURY            25            3             38            66
# 5       PUTNAM            38            1             19            58
# 7   MONTGOMERY            33            1             18            52
# 14     DICKSON            23            1             28            52
# 10     STEWART            29            2             14            45
# ...

# %%
details_cleaned['home_damage'] = details_cleaned['EVENT_NARRATIVE'].str.contains(r'(?i)(?=.*(home|business|residence|apartment))(?=.*(damage|repair|destroy|fell))')
# Out:
# C:\Users\plann\AppData\Local\Temp\ipykernel_48268\3529024316.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   details_cleaned['home_damage'] = details_cleaned['EVENT_NARRATIVE'].str.contains(r'(?i)(?=.*(home|business|residence|apartment))(?=.*(damage|repair|destroy|fell))')

# %%
details_cleaned.loc[details_cleaned['EVENT_NARRATIVE']== True]
# Out:
# Empty DataFrame
# Columns: [BEGIN_DATE, BEGIN_TIME, END_DATE, END_TIME, EPISODE_ID, EVENT_ID, EVENT_TYPE, CZ_TYPE, CZ_FIPS, CZ_NAME, WFO, CZ_TIMEZONE, INJURIES_DIRECT, INJURIES_INDIRECT, DEATHS_DIRECT, DEATHS_INDIRECT, DAMAGE_PROPERTY, DAMAGE_CROPS, SOURCE, MAGNITUDE, MAGNITUDE_TYPE, FLOOD_CAUSE, TOR_F_SCALE, TOR_LENGTH, TOR_WIDTH, TOR_OTHER_WFO, TOR_OTHER_CZ_FIPS, TOR_OTHER_CZ_NAME, BEGIN_RANGE, BEGIN_AZIMUTH, BEGIN_LOCATION, END_RANGE, END_AZIMUTH, END_LOCATION, BEGIN_LAT, BEGIN_LON, END_LAT, END_LON, EPISODE_NARRATIVE, EVENT_NARRATIVE, road_closures, power_outage, tree_damage, home_damage]
# Index: []
#
# [0 rows x 44 columns]
